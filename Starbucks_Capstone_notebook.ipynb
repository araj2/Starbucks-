# %% [markdown]
# # Starbucks Capstone Challenge
#
# ### Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has one product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (i.e., 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# # Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# **portfolio.json**
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational
# * difficulty (int) - minimum required spend to complete an offer
# * reward (int) - reward given for completing an offer
# * duration (int) - time for offer to be open, in days
# * channels (list of strings)
#
# **profile.json**
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# **transcript.json**
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record
#
# **Note:** If you are using the workspace, you will need to go to the terminal and run the command `conda update pandas` before reading in the files. This is because the version of pandas in the workspace cannot read in the transcript.json file correctly, but the newest version of pandas can. You can access the termnal from the orange icon in the top left of this notebook.
#
# You can see how to access the terminal and how the install works using the two images below.  First you need to access the terminal:
#
# <img src="pic1.png"/>
#
# Then you will want to run the above command:
#
# <img src="pic2.png"/>
#
# Finally, when you enter back into the notebook (use the jupyter icon again), you should be able to run the below cell without any errors.

# %%
import pandas as pd
import numpy as np
import math
import json
import seaborn as sns
% matplotlib inline

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %%
sns.distplot(profile['age'])

# %%
#some people are aged 120. This might be possible at the same it might not be. However it is advised to remove this age category
#since it will skew the data set. 
profile['age'] = profile['age'][profile['age']  <= 100]
profile = profile.dropna()

# %%
portfolio = portfolio.rename(columns = {'id':'offer_id'})

# %%
profile.head()
# Out:
#      age  became_member_on gender                                id    income
# 1   55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 3   75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef  100000.0
# 5   68.0          20180426      M  e2127556f4f64592b11af22de27a7932   70000.0
# 8   65.0          20180209      M  389bc3fa690240e798340f5a15918d5c   53000.0
# 12  58.0          20171111      M  2eeac8d8feae4a8cad5a6af0499a211d   51000.0

# %%
sns.distplot(portfolio['difficulty'])
sns.distplot(portfolio['reward'])

# %%
sns.distplot(profile['age'])

# %%
#we have now deleted all the missing values from the portfolio

# %%
sns.pairplot(profile, hue = "gender")

# %%
# we now realize that there is another gender than the traditional male and female categories that business usually target

# %%
profile = profile.rename(columns = {'id':'customer_id'})
profile.head()
# Out:
#      age  became_member_on gender                       customer_id    income
# 1   55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 3   75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef  100000.0
# 5   68.0          20180426      M  e2127556f4f64592b11af22de27a7932   70000.0
# 8   65.0          20180209      M  389bc3fa690240e798340f5a15918d5c   53000.0
# 12  58.0          20171111      M  2eeac8d8feae4a8cad5a6af0499a211d   51000.0

# %%
transcript = transcript.rename(columns = {'person':'customer_id'})
transcript.head()
# Out:
#             event                       customer_id  time  \
# 0  offer received  78afa995795e4d85b5d9ceeca43f5fef     0
# 1  offer received  a03223e636434f42ac4c3df47e8bac43     0
# 2  offer received  e2127556f4f64592b11af22de27a7932     0
# 3  offer received  8ec6ce2a7e7949b1bf142def7d0e0586     0
# 4  offer received  68617ca6246f4fbc85e91a2a49552598     0
#
#                                               value
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}

# %%
df = pd.merge(profile,transcript, on = 'customer_id')
df.head()
# Out:
#     age  became_member_on gender                       customer_id    income  \
# 0  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 1  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 2  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 3  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 4  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
#
#             event  time                                             value
# 0     transaction    18                                 {'amount': 21.51}
# 1     transaction   144                                 {'amount': 32.28}
# 2  offer received   408  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 3  offer received   504  {'offer id': '3f207df678b143eea3cee63160fa8bed'}
# 4     transaction   528                                 {'amount': 23.22}

# %%
value = pd.DataFrame.from_records(df['value'])
value.head()
# Out:
#    amount                          offer id offer_id  reward
# 0   21.51                               NaN      NaN     NaN
# 1   32.28                               NaN      NaN     NaN
# 2     NaN  9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN     NaN
# 3     NaN  3f207df678b143eea3cee63160fa8bed      NaN     NaN
# 4   23.22                               NaN      NaN     NaN

# %%
value.columns = value.columns.str.replace('offer id', 'offer_id')
s = value.stack()
value = s.unstack()

# %%
value['conversion'] = value['reward']
value['conversion'] = value['conversion'].fillna(0)
value['amount'] = value['amount'].fillna(0)

# %%
portfolio.head()
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
#
#                            offer_id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5

# %%
df = df.join(value)
# Out:
#          age  became_member_on gender                       customer_id  \
# 0       55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 1       55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 2       55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 3       55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 4       55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 5       55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 6       75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 7       75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 8       75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 9       75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 10      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 11      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 12      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 13      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 14      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 15      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 16      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 17      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 18      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 19      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 20      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 21      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 22      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 23      75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 24      68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# 25      68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# 26      68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# 27      68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# 28      68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# 29      68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# ...      ...               ...    ...                               ...
# 272634  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272635  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272636  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272637  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272638  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272639  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272640  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272641  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272642  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272643  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272644  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272645  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272646  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272647  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272648  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272649  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 272650  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272651  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272652  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272653  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272654  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272655  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272656  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272657  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272658  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272659  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272660  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272661  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272662  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
# 272663  62.0          20170722      F  e4052622e5ba45a8b96b59aba68cf068
#
#           income            event  time  \
# 0       112000.0      transaction    18
# 1       112000.0      transaction   144
# 2       112000.0   offer received   408
# 3       112000.0   offer received   504
# 4       112000.0      transaction   528
# 5       112000.0  offer completed   528
# 6       100000.0   offer received     0
# 7       100000.0     offer viewed     6
# 8       100000.0      transaction   132
# 9       100000.0  offer completed   132
# 10      100000.0      transaction   144
# 11      100000.0   offer received   168
# 12      100000.0     offer viewed   216
# 13      100000.0      transaction   222
# 14      100000.0      transaction   240
# 15      100000.0      transaction   378
# 16      100000.0   offer received   408
# 17      100000.0     offer viewed   408
# 18      100000.0   offer received   504
# 19      100000.0      transaction   510
# 20      100000.0  offer completed   510
# 21      100000.0  offer completed   510
# 22      100000.0      transaction   534
# 23      100000.0     offer viewed   582
# 24       70000.0   offer received     0
# 25       70000.0     offer viewed    18
# 26       70000.0      transaction   288
# 27       70000.0      transaction   294
# 28       70000.0   offer received   336
# 29       70000.0   offer received   408
# ...          ...              ...   ...
# 272634   50000.0  offer completed   360
# 272635   50000.0      transaction   372
# 272636   50000.0   offer received   408
# 272637   50000.0      transaction   414
# 272638   50000.0  offer completed   414
# 272639   50000.0      transaction   426
# 272640   50000.0      transaction   504
# 272641   50000.0     offer viewed   516
# 272642   50000.0      transaction   522
# 272643   50000.0   offer received   576
# 272644   50000.0      transaction   594
# 272645   50000.0  offer completed   594
# 272646   50000.0     offer viewed   624
# 272647   50000.0      transaction   636
# 272648   50000.0      transaction   660
# 272649   50000.0      transaction   684
# 272650   82000.0   offer received     0
# 272651   82000.0     offer viewed     6
# 272652   82000.0      transaction    54
# 272653   82000.0  offer completed    54
# 272654   82000.0      transaction    84
# 272655   82000.0      transaction    96
# 272656   82000.0   offer received   336
# 272657   82000.0   offer received   408
# 272658   82000.0      transaction   480
# 272659   82000.0  offer completed   480
# 272660   82000.0      transaction   486
# 272661   82000.0     offer viewed   546
# 272662   82000.0   offer received   576
# 272663   82000.0      transaction   690
#
#                                                     value  amount  \
# 0                                       {'amount': 21.51}   21.51
# 1                                       {'amount': 32.28}   32.28
# 2        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}    0.00
# 3        {'offer id': '3f207df678b143eea3cee63160fa8bed'}    0.00
# 4                                       {'amount': 23.22}   23.22
# 5       {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...    0.00
# 6        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}    0.00
# 7        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}    0.00
# 8                                       {'amount': 19.89}   19.89
# 9       {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...    0.00
# 10                                      {'amount': 17.78}   17.78
# 11       {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}    0.00
# 12       {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}    0.00
# 13                                      {'amount': 19.67}   19.67
# 14                                      {'amount': 29.72}   29.72
# 15                                      {'amount': 23.93}   23.93
# 16       {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}    0.00
# 17       {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}    0.00
# 18       {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}    0.00
# 19                                      {'amount': 21.72}   21.72
# 20      {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...    0.00
# 21      {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...    0.00
# 22                                      {'amount': 26.56}   26.56
# 23       {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}    0.00
# 24       {'offer id': '2906b810c7d4411798c6938adc9daaa5'}    0.00
# 25       {'offer id': '2906b810c7d4411798c6938adc9daaa5'}    0.00
# 26                                      {'amount': 17.88}   17.88
# 27                                      {'amount': 21.43}   21.43
# 28       {'offer id': '3f207df678b143eea3cee63160fa8bed'}    0.00
# 29       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}    0.00
# ...                                                   ...     ...
# 272634  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...    0.00
# 272635                                   {'amount': 13.1}   13.10
# 272636   {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}    0.00
# 272637                                  {'amount': 11.03}   11.03
# 272638  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...    0.00
# 272639                                  {'amount': 13.13}   13.13
# 272640                                  {'amount': 17.26}   17.26
# 272641   {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}    0.00
# 272642                                   {'amount': 31.6}   31.60
# 272643   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}    0.00
# 272644                                  {'amount': 12.57}   12.57
# 272645  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...    0.00
# 272646   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}    0.00
# 272647                                  {'amount': 14.55}   14.55
# 272648                                  {'amount': 20.27}   20.27
# 272649                                  {'amount': 11.11}   11.11
# 272650   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}    0.00
# 272651   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}    0.00
# 272652                                  {'amount': 21.55}   21.55
# 272653  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...    0.00
# 272654                                  {'amount': 25.19}   25.19
# 272655                                  {'amount': 21.53}   21.53
# 272656   {'offer id': '3f207df678b143eea3cee63160fa8bed'}    0.00
# 272657   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}    0.00
# 272658                                  {'amount': 30.57}   30.57
# 272659  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...    0.00
# 272660                                  {'amount': 19.47}   19.47
# 272661   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}    0.00
# 272662   {'offer id': '3f207df678b143eea3cee63160fa8bed'}    0.00
# 272663                                  {'amount': 24.71}   24.71
#
#                                 offer_id reward  conversion
# 0                                    NaN    NaN         0.0
# 1                                    NaN    NaN         0.0
# 2       9b98b8c7a33c4b65b9aebfe6a799e6d9    NaN         0.0
# 3       3f207df678b143eea3cee63160fa8bed    NaN         0.0
# 4                                    NaN    NaN         0.0
# 5       9b98b8c7a33c4b65b9aebfe6a799e6d9      5         5.0
# 6       9b98b8c7a33c4b65b9aebfe6a799e6d9    NaN         0.0
# 7       9b98b8c7a33c4b65b9aebfe6a799e6d9    NaN         0.0
# 8                                    NaN    NaN         0.0
# 9       9b98b8c7a33c4b65b9aebfe6a799e6d9      5         5.0
# 10                                   NaN    NaN         0.0
# 11      5a8bc65990b245e5a138643cd4eb9837    NaN         0.0
# 12      5a8bc65990b245e5a138643cd4eb9837    NaN         0.0
# 13                                   NaN    NaN         0.0
# 14                                   NaN    NaN         0.0
# 15                                   NaN    NaN         0.0
# 16      ae264e3637204a6fb9bb56bc8210ddfd    NaN         0.0
# 17      ae264e3637204a6fb9bb56bc8210ddfd    NaN         0.0
# 18      f19421c1d4aa40978ebb69ca19b0e20d    NaN         0.0
# 19                                   NaN    NaN         0.0
# 20      ae264e3637204a6fb9bb56bc8210ddfd     10        10.0
# 21      f19421c1d4aa40978ebb69ca19b0e20d      5         5.0
# 22                                   NaN    NaN         0.0
# 23      f19421c1d4aa40978ebb69ca19b0e20d    NaN         0.0
# 24      2906b810c7d4411798c6938adc9daaa5    NaN         0.0
# 25      2906b810c7d4411798c6938adc9daaa5    NaN         0.0
# 26                                   NaN    NaN         0.0
# 27                                   NaN    NaN         0.0
# 28      3f207df678b143eea3cee63160fa8bed    NaN         0.0
# 29      9b98b8c7a33c4b65b9aebfe6a799e6d9    NaN         0.0
# ...                                  ...    ...         ...
# 272634  4d5c57ea9a6940dd891ad53e9dbe8da0     10        10.0
# 272635                               NaN    NaN         0.0
# 272636  9b98b8c7a33c4b65b9aebfe6a799e6d9    NaN         0.0
# 272637                               NaN    NaN         0.0
# 272638  9b98b8c7a33c4b65b9aebfe6a799e6d9      5         5.0
# 272639                               NaN    NaN         0.0
# 272640                               NaN    NaN         0.0
# 272641  9b98b8c7a33c4b65b9aebfe6a799e6d9    NaN         0.0
# 272642                               NaN    NaN         0.0
# 272643  ae264e3637204a6fb9bb56bc8210ddfd    NaN         0.0
# 272644                               NaN    NaN         0.0
# 272645  ae264e3637204a6fb9bb56bc8210ddfd     10        10.0
# 272646  ae264e3637204a6fb9bb56bc8210ddfd    NaN         0.0
# 272647                               NaN    NaN         0.0
# 272648                               NaN    NaN         0.0
# 272649                               NaN    NaN         0.0
# 272650  2298d6c36e964ae4a3e7e9706d1fb8c2    NaN         0.0
# 272651  2298d6c36e964ae4a3e7e9706d1fb8c2    NaN         0.0
# 272652                               NaN    NaN         0.0
# 272653  2298d6c36e964ae4a3e7e9706d1fb8c2      3         3.0
# 272654                               NaN    NaN         0.0
# 272655                               NaN    NaN         0.0
# 272656  3f207df678b143eea3cee63160fa8bed    NaN         0.0
# 272657  f19421c1d4aa40978ebb69ca19b0e20d    NaN         0.0
# 272658                               NaN    NaN         0.0
# 272659  f19421c1d4aa40978ebb69ca19b0e20d      5         5.0
# 272660                               NaN    NaN         0.0
# 272661  f19421c1d4aa40978ebb69ca19b0e20d    NaN         0.0
# 272662  3f207df678b143eea3cee63160fa8bed    NaN         0.0
# 272663                               NaN    NaN         0.0
#
# [272664 rows x 12 columns]

# %%
df_offer = df[df['offer_id'].notna() == True]
df_purchase = df[df['offer_id'].notna() == False]

# %%
df_purchase = df_purchase.drop(columns = {'value','offer_id','reward','conversion'})

# %%
df1 = pd.merge(df_offer, portfolio, on = ['offer_id', how = 'outer') # pd.merge(df1, df2, on='Customer_id', how='inner')

# %%
df1
# Out:
#          age  became_member_on gender                       customer_id  \
# 0       55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 1       55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b
# 2       75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 3       75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 4       75.0          20170509      F  78afa995795e4d85b5d9ceeca43f5fef
# 5       68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# 6       68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# 7       68.0          20180426      M  e2127556f4f64592b11af22de27a7932
# 8       65.0          20180209      M  389bc3fa690240e798340f5a15918d5c
# 9       65.0          20180209      M  389bc3fa690240e798340f5a15918d5c
# 10      65.0          20180209      M  389bc3fa690240e798340f5a15918d5c
# 11      65.0          20180209      M  389bc3fa690240e798340f5a15918d5c
# 12      65.0          20180209      M  389bc3fa690240e798340f5a15918d5c
# 13      57.0          20171231      M  6445de3b47274c759400cd68131d91b4
# 14      57.0          20171231      M  6445de3b47274c759400cd68131d91b4
# 15      57.0          20171231      M  6445de3b47274c759400cd68131d91b4
# 16      61.0          20180501      F  a448667f336b42c9a66fc5ffd5d73772
# 17      56.0          20180428      F  d058f73bf8674a26a95227db098147b1
# 18      56.0          20180428      F  d058f73bf8674a26a95227db098147b1
# 19      56.0          20180428      F  d058f73bf8674a26a95227db098147b1
# 20      56.0          20180428      F  d058f73bf8674a26a95227db098147b1
# 21      33.0          20170926      F  c6c9884912c645429f3333f912b55f44
# 22      59.0          20150121      M  ebe7ef46ea6f4963a7dd49f501b26779
# 23      59.0          20150121      M  ebe7ef46ea6f4963a7dd49f501b26779
# 24      59.0          20150121      M  ebe7ef46ea6f4963a7dd49f501b26779
# 25      53.0          20170916      O  d1ede868e29245ea91818a903fec04c6
# 26      96.0          20171117      F  868317b9be554cb18e50bc68484749a2
# 27      96.0          20171117      F  868317b9be554cb18e50bc68484749a2
# 28      40.0          20160709      M  f082d80f0aac47a99173ba8ef8fc1909
# 29      40.0          20160709      M  f082d80f0aac47a99173ba8ef8fc1909
# ...      ...               ...    ...                               ...
# 148724  77.0          20170425      F  1c35792f115f4d06b138a63edf84ee4d
# 148725  77.0          20170425      F  1c35792f115f4d06b138a63edf84ee4d
# 148726  71.0          20180110      F  3d2ae0a586794fbe881dace3aa2258c6
# 148727  71.0          20180110      F  3d2ae0a586794fbe881dace3aa2258c6
# 148728  48.0          20171228      F  24f56b5e1849462093931b164eb803b5
# 148729  48.0          20171228      F  24f56b5e1849462093931b164eb803b5
# 148730  65.0          20170705      F  22ce932a14c34f2fbd3d36d4f3a598d5
# 148731  65.0          20170705      F  22ce932a14c34f2fbd3d36d4f3a598d5
# 148732  21.0          20171030      M  a16a9c5a2aaa4b14a3ae6b94080a2812
# 148733  21.0          20171030      M  a16a9c5a2aaa4b14a3ae6b94080a2812
# 148734  25.0          20151020      M  82212ba0e8a74861bf1e20cd6f2e41ba
# 148735  25.0          20151020      M  82212ba0e8a74861bf1e20cd6f2e41ba
# 148736  57.0          20180524      F  1fc56d7bf27d4d3888625d67fb2ea306
# 148737  57.0          20180524      F  1fc56d7bf27d4d3888625d67fb2ea306
# 148738  52.0          20180522      F  6e71b66784844d1ab8376ac8ab096d4b
# 148739  52.0          20180522      F  6e71b66784844d1ab8376ac8ab096d4b
# 148740  52.0          20180522      F  6e71b66784844d1ab8376ac8ab096d4b
# 148741  39.0          20160921      F  122c0c2a3c2540848f8c3fdc37e97639
# 148742  39.0          20160921      F  122c0c2a3c2540848f8c3fdc37e97639
# 148743  39.0          20160921      F  122c0c2a3c2540848f8c3fdc37e97639
# 148744  29.0          20170220      F  54bead4179c44b71acc4e8398181d183
# 148745  29.0          20170220      F  54bead4179c44b71acc4e8398181d183
# 148746  29.0          20170220      F  54bead4179c44b71acc4e8398181d183
# 148747  72.0          20150404      F  ff737c250d2343729ade04c4f6eb1001
# 148748  72.0          20150404      F  ff737c250d2343729ade04c4f6eb1001
# 148749  45.0          20180604      F  6d5f3a774f3d4714ab0c092238f3a1d7
# 148750  45.0          20180604      F  6d5f3a774f3d4714ab0c092238f3a1d7
# 148751  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 148752  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
# 148753  83.0          20160307      F  9dc1421481194dcd9400aec7c9ae6366
#
#           income            event  time  \
# 0       112000.0   offer received   408
# 1       112000.0  offer completed   528
# 2       100000.0   offer received     0
# 3       100000.0     offer viewed     6
# 4       100000.0  offer completed   132
# 5        70000.0   offer received   408
# 6        70000.0     offer viewed   420
# 7        70000.0  offer completed   522
# 8        53000.0   offer received   168
# 9        53000.0     offer viewed   192
# 10       53000.0   offer received   408
# 11       53000.0     offer viewed   438
# 12       53000.0  offer completed   498
# 13       42000.0   offer received   336
# 14       42000.0   offer received   504
# 15       42000.0  offer completed   516
# 16       40000.0   offer received     0
# 17       88000.0   offer received   504
# 18       88000.0     offer viewed   522
# 19       88000.0   offer received   576
# 20       88000.0     offer viewed   606
# 21       52000.0   offer received   576
# 22       41000.0   offer received     0
# 23       41000.0   offer received   576
# 24       41000.0     offer viewed   714
# 25       52000.0   offer received   576
# 26       89000.0   offer received   408
# 27       89000.0  offer completed   468
# 28       33000.0   offer received     0
# 29       33000.0  offer completed    12
# ...          ...              ...   ...
# 148724   71000.0     offer viewed   192
# 148725   71000.0  offer completed   198
# 148726   64000.0   offer received     0
# 148727   64000.0     offer viewed     0
# 148728   80000.0   offer received   408
# 148729   80000.0     offer viewed   426
# 148730   35000.0   offer received   336
# 148731   35000.0  offer completed   354
# 148732   35000.0   offer received   336
# 148733   35000.0     offer viewed   366
# 148734   45000.0   offer received   336
# 148735   45000.0     offer viewed   372
# 148736   55000.0   offer received   336
# 148737   55000.0     offer viewed   426
# 148738   75000.0   offer received     0
# 148739   75000.0  offer completed     6
# 148740   75000.0     offer viewed    18
# 148741   54000.0   offer received     0
# 148742   54000.0     offer viewed     6
# 148743   54000.0  offer completed    36
# 148744   58000.0   offer received   336
# 148745   58000.0     offer viewed   348
# 148746   58000.0  offer completed   360
# 148747   65000.0   offer received     0
# 148748   65000.0     offer viewed    96
# 148749   54000.0   offer received   336
# 148750   54000.0     offer viewed   402
# 148751   50000.0   offer received   336
# 148752   50000.0     offer viewed   342
# 148753   50000.0  offer completed   360
#
#                                                     value  amount  \
# 0        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 1       {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0.0
# 2        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 3        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 4       {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0.0
# 5        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 6        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 7       {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0.0
# 8        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 9        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 10       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 11       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 12      {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0.0
# 13       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 14       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 15      {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0.0
# 16       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 17       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 18       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 19       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 20       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 21       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 22       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 23       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 24       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 25       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 26       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 27      {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0.0
# 28       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0.0
# 29      {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...     0.0
# ...                                                   ...     ...
# 148724   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148725  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0.0
# 148726   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148727   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148728   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148729   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148730   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148731  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0.0
# 148732   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148733   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148734   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148735   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148736   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148737   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148738   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148739  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0.0
# 148740   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148741   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148742   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148743  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0.0
# 148744   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148745   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148746  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0.0
# 148747   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148748   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148749   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148750   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148751   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148752   {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0.0
# 148753  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...     0.0
#
#                                 offer_id reward_x  conversion  \
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 1       9b98b8c7a33c4b65b9aebfe6a799e6d9        5         5.0
# 2       9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 3       9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 4       9b98b8c7a33c4b65b9aebfe6a799e6d9        5         5.0
# 5       9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 6       9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 7       9b98b8c7a33c4b65b9aebfe6a799e6d9        5         5.0
# 8       9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 9       9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 10      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 11      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 12      9b98b8c7a33c4b65b9aebfe6a799e6d9        5         5.0
# 13      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 14      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 15      9b98b8c7a33c4b65b9aebfe6a799e6d9        5         5.0
# 16      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 17      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 18      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 19      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 20      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 21      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 22      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 23      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 24      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 25      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 26      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 27      9b98b8c7a33c4b65b9aebfe6a799e6d9        5         5.0
# 28      9b98b8c7a33c4b65b9aebfe6a799e6d9      NaN         0.0
# 29      9b98b8c7a33c4b65b9aebfe6a799e6d9        5         5.0
# ...                                  ...      ...         ...
# 148724  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148725  4d5c57ea9a6940dd891ad53e9dbe8da0       10        10.0
# 148726  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148727  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148728  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148729  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148730  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148731  4d5c57ea9a6940dd891ad53e9dbe8da0       10        10.0
# 148732  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148733  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148734  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148735  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148736  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148737  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148738  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148739  4d5c57ea9a6940dd891ad53e9dbe8da0       10        10.0
# 148740  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148741  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148742  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148743  4d5c57ea9a6940dd891ad53e9dbe8da0       10        10.0
# 148744  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148745  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148746  4d5c57ea9a6940dd891ad53e9dbe8da0       10        10.0
# 148747  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148748  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148749  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148750  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148751  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148752  4d5c57ea9a6940dd891ad53e9dbe8da0      NaN         0.0
# 148753  4d5c57ea9a6940dd891ad53e9dbe8da0       10        10.0
#
#                             channels  difficulty  duration offer_type  \
# 0               [web, email, mobile]           5         7       bogo
# 1               [web, email, mobile]           5         7       bogo
# 2               [web, email, mobile]           5         7       bogo
# 3               [web, email, mobile]           5         7       bogo
# 4               [web, email, mobile]           5         7       bogo
# 5               [web, email, mobile]           5         7       bogo
# 6               [web, email, mobile]           5         7       bogo
# 7               [web, email, mobile]           5         7       bogo
# 8               [web, email, mobile]           5         7       bogo
# 9               [web, email, mobile]           5         7       bogo
# 10              [web, email, mobile]           5         7       bogo
# 11              [web, email, mobile]           5         7       bogo
# 12              [web, email, mobile]           5         7       bogo
# 13              [web, email, mobile]           5         7       bogo
# 14              [web, email, mobile]           5         7       bogo
# 15              [web, email, mobile]           5         7       bogo
# 16              [web, email, mobile]           5         7       bogo
# 17              [web, email, mobile]           5         7       bogo
# 18              [web, email, mobile]           5         7       bogo
# 19              [web, email, mobile]           5         7       bogo
# 20              [web, email, mobile]           5         7       bogo
# 21              [web, email, mobile]           5         7       bogo
# 22              [web, email, mobile]           5         7       bogo
# 23              [web, email, mobile]           5         7       bogo
# 24              [web, email, mobile]           5         7       bogo
# 25              [web, email, mobile]           5         7       bogo
# 26              [web, email, mobile]           5         7       bogo
# 27              [web, email, mobile]           5         7       bogo
# 28              [web, email, mobile]           5         7       bogo
# 29              [web, email, mobile]           5         7       bogo
# ...                              ...         ...       ...        ...
# 148724  [web, email, mobile, social]          10         5       bogo
# 148725  [web, email, mobile, social]          10         5       bogo
# 148726  [web, email, mobile, social]          10         5       bogo
# 148727  [web, email, mobile, social]          10         5       bogo
# 148728  [web, email, mobile, social]          10         5       bogo
# 148729  [web, email, mobile, social]          10         5       bogo
# 148730  [web, email, mobile, social]          10         5       bogo
# 148731  [web, email, mobile, social]          10         5       bogo
# 148732  [web, email, mobile, social]          10         5       bogo
# 148733  [web, email, mobile, social]          10         5       bogo
# 148734  [web, email, mobile, social]          10         5       bogo
# 148735  [web, email, mobile, social]          10         5       bogo
# 148736  [web, email, mobile, social]          10         5       bogo
# 148737  [web, email, mobile, social]          10         5       bogo
# 148738  [web, email, mobile, social]          10         5       bogo
# 148739  [web, email, mobile, social]          10         5       bogo
# 148740  [web, email, mobile, social]          10         5       bogo
# 148741  [web, email, mobile, social]          10         5       bogo
# 148742  [web, email, mobile, social]          10         5       bogo
# 148743  [web, email, mobile, social]          10         5       bogo
# 148744  [web, email, mobile, social]          10         5       bogo
# 148745  [web, email, mobile, social]          10         5       bogo
# 148746  [web, email, mobile, social]          10         5       bogo
# 148747  [web, email, mobile, social]          10         5       bogo
# 148748  [web, email, mobile, social]          10         5       bogo
# 148749  [web, email, mobile, social]          10         5       bogo
# 148750  [web, email, mobile, social]          10         5       bogo
# 148751  [web, email, mobile, social]          10         5       bogo
# 148752  [web, email, mobile, social]          10         5       bogo
# 148753  [web, email, mobile, social]          10         5       bogo
#
#         reward_y
# 0              5
# 1              5
# 2              5
# 3              5
# 4              5
# 5              5
# 6              5
# 7              5
# 8              5
# 9              5
# 10             5
# 11             5
# 12             5
# 13             5
# 14             5
# 15             5
# 16             5
# 17             5
# 18             5
# 19             5
# 20             5
# 21             5
# 22             5
# 23             5
# 24             5
# 25             5
# 26             5
# 27             5
# 28             5
# 29             5
# ...          ...
# 148724        10
# 148725        10
# 148726        10
# 148727        10
# 148728        10
# 148729        10
# 148730        10
# 148731        10
# 148732        10
# 148733        10
# 148734        10
# 148735        10
# 148736        10
# 148737        10
# 148738        10
# 148739        10
# 148740        10
# 148741        10
# 148742        10
# 148743        10
# 148744        10
# 148745        10
# 148746        10
# 148747        10
# 148748        10
# 148749        10
# 148750        10
# 148751        10
# 148752        10
# 148753        10
#
# [148754 rows x 17 columns]

# %%
df1 = pd.merge(df_offer,portfolio, on = 'offer_id')

# %%
df1 = df1.drop(columns = 'reward_y')
df1 = df1.rename(columns = {'reward_x':'reward'})
df1 = df1.drop(columns = 'value')

# %%
df1['reward'] = df1['reward'].fillna(0)
df1['conversion'] = df1['reward']/df1['conversion']
df1['conversion'] = df1['conversion'].fillna(0)

# %%
sns.countplot(df1['offer_type'])

# %%
sns.countplot(df1['reward'])

# %%
df1['conversion'].mean()
# Out:
# 0.21802438926012074

# %%
sns.distplot(df1['age'])

# %%
sns.distplot(df1['income'])

# %%
sns.countplot(df1['channels'].astype(str))
figsize = (10,10)

# %%
portfolio
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
# 5  [web, email, mobile, social]           7         7
# 6  [web, email, mobile, social]          10        10
# 7       [email, mobile, social]           0         3
# 8  [web, email, mobile, social]           5         5
# 9          [web, email, mobile]          10         7
#
#                            offer_id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       discount       3
# 6  fafdcd668e3743c1bb461111dcafc2a4       discount       2
# 7  5a8bc65990b245e5a138643cd4eb9837  informational       0
# 8  f19421c1d4aa40978ebb69ca19b0e20d           bogo       5
# 9  2906b810c7d4411798c6938adc9daaa5       discount       2

# %%
portfolio
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
# 5  [web, email, mobile, social]           7         7
# 6  [web, email, mobile, social]          10        10
# 7       [email, mobile, social]           0         3
# 8  [web, email, mobile, social]           5         5
# 9          [web, email, mobile]          10         7
#
#                            offer_id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       discount       3
# 6  fafdcd668e3743c1bb461111dcafc2a4       discount       2
# 7  5a8bc65990b245e5a138643cd4eb9837  informational       0
# 8  f19421c1d4aa40978ebb69ca19b0e20d           bogo       5
# 9  2906b810c7d4411798c6938adc9daaa5       discount       2

# %%
df = df.drop(columns = 'value')
df = df.rename(columns = {'offer_id':'used_offer_id','offer id':'offer_id'})

# %%
df.head()
# Out:
#     age  became_member_on gender                       customer_id    income  \
# 0  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 1  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 2  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 3  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 4  55.0          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
#
#             event  time                                             value  \
# 0     transaction    18                                 {'amount': 21.51}
# 1     transaction   144                                 {'amount': 32.28}
# 2  offer received   408  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 3  offer received   504  {'offer id': '3f207df678b143eea3cee63160fa8bed'}
# 4     transaction   528                                 {'amount': 23.22}
#
#    amount                          offer_id reward  conversion channels
# 0   21.51                               NaN    NaN         0.0
# 1   32.28                               NaN    NaN         0.0
# 2    0.00  9b98b8c7a33c4b65b9aebfe6a799e6d9    NaN         0.0
# 3    0.00  3f207df678b143eea3cee63160fa8bed    NaN         0.0
# 4   23.22                               NaN    NaN         0.0

# %%
portfolio
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
# 5  [web, email, mobile, social]           7         7
# 6  [web, email, mobile, social]          10        10
# 7       [email, mobile, social]           0         3
# 8  [web, email, mobile, social]           5         5
# 9          [web, email, mobile]          10         7
#
#                                  id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       discount       3
# 6  fafdcd668e3743c1bb461111dcafc2a4       discount       2
# 7  5a8bc65990b245e5a138643cd4eb9837  informational       0
# 8  f19421c1d4aa40978ebb69ca19b0e20d           bogo       5
# 9  2906b810c7d4411798c6938adc9daaa5       discount       2

# %%
# if the customer didnt buy transaction we replaced that amount by 0, if the customer did

# %%
df['offer_id'] = df['offer_id'].map({'ae264e3637204a6fb9bb56bc8210ddfd': 1, 
                                     '4d5c57ea9a6940dd891ad53e9dbe8da0': 2,
                                     '3f207df678b143eea3cee63160fa8bed': 3,
                                     '9b98b8c7a33c4b65b9aebfe6a799e6d9': 4,
                                     '0b1e1539f2cc45b7b9fa7c272da2e1d7': 5,
                                     '2298d6c36e964ae4a3e7e9706d1fb8c2': 6,
                                     'fafdcd668e3743c1bb461111dcafc2a4': 7,
                                     '5a8bc65990b245e5a138643cd4eb9837': 8,
                                     'f19421c1d4aa40978ebb69ca19b0e20d': 9, 
                                     '2906b810c7d4411798c6938adc9daaa5': 10,})

# %%
df['reward'] = value['reward'].fillna(0)
df['conversion'] = value['conversion']/df['reward']
df['conversion'] = df['conversion'].fillna(0)
df['offer_id'] = df['offer_id'].fillna(0)

# %%
sns.pairplot(df)

# %%
sns.countplot(df['event'])

# %%
sns.distplot(portfolio['difficulty'])
sns.distplot(portfolio['reward'])

# %%
portfolio['offer_id'] = portfolio['offer_id'].map({'ae264e3637204a6fb9bb56bc8210ddfd': 1, 
                                     '4d5c57ea9a6940dd891ad53e9dbe8da0': 2,
                                     '3f207df678b143eea3cee63160fa8bed': 3,
                                     '9b98b8c7a33c4b65b9aebfe6a799e6d9': 4,
                                     '0b1e1539f2cc45b7b9fa7c272da2e1d7': 5,
                                     '2298d6c36e964ae4a3e7e9706d1fb8c2': 6,
                                     'fafdcd668e3743c1bb461111dcafc2a4': 7,
                                     '5a8bc65990b245e5a138643cd4eb9837': 8,
                                     'f19421c1d4aa40978ebb69ca19b0e20d': 9, 
                                     '2906b810c7d4411798c6938adc9daaa5': 10,})

# %%
df = pd.merge(df,portfolio,on = 'offer_id')
#map values from one dataframe to another

# %%
df
# Out:
# Empty DataFrame
# Columns: [age, became_member_on, gender, customer_id, income, event, time, amount, offer_id, used_offer_id, reward_x, conversion, channels, difficulty, duration, offer_type, reward_y, code]
# Index: []

# %%
#this countplot shows how many customers acted on their offers
sns.countplot(df['offer_id'], sort =asc)

# %%
sns.boxplot(x="offer_id", y="reward", data=df)
# Add in points to show each observation
